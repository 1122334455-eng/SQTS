# %% [markdown]
# ## STEP 1 — Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Better visuals
sns.set(style="whitegrid")

# %% [markdown]
# ## STEP 2 — Dataset Load

# %%
df = pd.read_csv("titanic_cleaned.csv")
df.head()
# Out:
#    PassengerId  Survived                                          Name  \
# 0            1         0                       Braund, Mr. Owen Harris
# 1            3         1                        Heikkinen, Miss. Laina
# 2            4         1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3            5         0                      Allen, Mr. William Henry
# 4            6         0                              Moran, Mr. James
#
#         Age  SibSp  Parch            Ticket      Fare  Sex_male  Embarked_Q  \
# 0  0.271174    0.2    0.0         A/5 21171  0.111538      True       False
# 1  0.321438    0.0    0.0  STON/O2. 3101282  0.121923     False       False
# 2  0.434531    0.2    0.0            113803  0.816923     False       False
# 3  0.434531    0.0    0.0            373450  0.123846      True       False
# 4  0.346569    0.0    0.0            330877  0.130128      True        True
#
#    Embarked_S  Pclass_2  Pclass_3
# 0        True     False      True
# ...

# %% [markdown]
# ## STEP 3 — Basic Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  775 non-null    int64
#  1   Survived     775 non-null    int64
#  2   Name         775 non-null    object
#  3   Age          775 non-null    float64
#  4   SibSp        775 non-null    float64
#  5   Parch        775 non-null    float64
#  6   Ticket       775 non-null    object
#  7   Fare         775 non-null    float64
#  8   Sex_male     775 non-null    bool
#  9   Embarked_Q   775 non-null    bool
#  10  Embarked_S   775 non-null    bool
#  11  Pclass_2     775 non-null    bool
#  12  Pclass_3     775 non-null    bool
# dtypes: bool(5), float64(4), int64(2), object(2)
# memory usage: 52.3+ KB

# %% [markdown]
# ## STEP 4 — Shape & Columns

# %%
print("Shape:", df.shape)
# Out:
# Shape: (775, 13)

# %%
print("Columns:", df.columns)
# Out:
# Columns: Index(['PassengerId', 'Survived', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Sex_male', 'Embarked_Q', 'Embarked_S', 'Pclass_2', 'Pclass_3'],
#       dtype='object')

# %% [markdown]
# ## STEP 5 — Descriptive Statistics

# %%
df.describe()
# Out:
#        PassengerId    Survived         Age       SibSp       Parch        Fare
# count   775.000000  775.000000  775.000000  775.000000  775.000000  775.000000
# mean    445.806452    0.339355    0.355978    0.087484    0.056774    0.274186
# std     260.116285    0.473796    0.160620    0.179968    0.130986    0.208894
# min       1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     213.500000    0.000000    0.271174    0.000000    0.000000    0.121474
# 50%     450.000000    0.000000    0.346569    0.000000    0.000000    0.200000
# 75%     670.500000    1.000000    0.421965    0.200000    0.000000    0.400000
# max     891.000000    1.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# ## STEP 6 — Missing Values Check

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Name           0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Sex_male       0
# Embarked_Q     0
# Embarked_S     0
# Pclass_2       0
# Pclass_3       0
# dtype: int64

# %% [markdown]
# ## STEP 7 — Histograms

# %%
df.hist(figsize=(12,8))
plt.show()

# %% [markdown]
# ## STEP 8 — Boxplot (Outliers)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## STEP 9 — Correlation Heatmap

# %%
plt.figure(figsize=(12,7))

numeric_df = df.select_dtypes(include=['int64','float64','bool'])

sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Titanic Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # FINAL INSIGHTS

# %% [markdown]
# 1️⃣ Dataset Clean
#
# No missing values found in any column.
# This shows proper preprocessing and data quality.

# %% [markdown]
# 2️⃣ Survival Rate Low
#
# Mean survival = 0.33
# 👉 Around 33% passengers survived

# %% [markdown]
# 3️⃣ Age Distribution Normal
#
# Most passengers mid-age range me hain
#
# Age normalized hai (0–1 scale)
#
# 👉 ML-ready feature

# %% [markdown]
# 4️⃣ Fare Strong Indicator
#
# Heatmap me:
#
# Fare vs Survival positive correlation (~0.23)
#
# 👉 Higher fare → higher survival chance

# %% [markdown]
# 5️⃣ Gender Strong Factor
#
# Sex_male vs Survived = negative correlation (-0.50)
#
# 👉 Females more likely survived
# (Real Titanic fact 💯)

# %% [markdown]
# 6️⃣ Passenger Class
#
# Pclass_3 negatively correlated with survival
#
# 👉 Lower class passengers less survival

# %% [markdown]
# 7️⃣ Family Features Useful
#
# SibSp & Parch moderate correlation
#
# 👉 Family presence affects survival patterns

# %% [markdown]
# Conclusion
#
# The dataset is clean, well-preprocessed, and ready for machine learning modeling.
# Key survival factors: gender, fare, passenger class
